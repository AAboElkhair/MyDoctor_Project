# %% [markdown]
# # **Breath sounds**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Breath sounds are the noises produced by the structures of the lungs during breathing.
# Breath sounds may be heard with a stethoscope during inspiration and expiration—a practice known as auscultation.
#
# Listening to the lungs is best done in a quiet room with a person sitting with their mouth open. Ideally, auscultation should be performed beneath clothing (or, next best, through as little clothing as possible).
# The exam should extend from the top of the lungs down to the lower lung fields, with auscultation performed on the anterior chest, posterior chest, as well as under the armpits (mid-axillary region).

# %% [markdown]
# There are several characteristics that healthcare providers note when listening to the lungs.

# %% [markdown]
# **Why using Deep Learning in this ?**

# %% [markdown]
# It is a subset of Neural Networks ( a computing systems which is insprired by biological neural networks ). And by stacking a lot of Neural Networks layers, we will get a Deep Learning model which might contains multiple billions parameters and is capable of handle very complicated problems that no classical algorithm can be effective.

# %% [markdown]
# Deep Learning is especially powerful with unstructrured data (Image, Text, Sound, Video, …).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os
import glob
import fnmatch
import pandas as pd
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd
import json
import math
import tensorflow as tf
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
data_path = "/content/drive/MyDrive/heart_sound"

# %%
tarin_data = data_path +"/train/"
val_data   = data_path + "/val/"

train_healthy_data   = tarin_data + '/healthy/'
train_unhealthy_data = tarin_data + '/unhealthy/'
val_healthy_data     = val_data   + '/healthy/'
val_unhealthy_data   = val_data   + '/unhealthy/'

# %%
print(os.listdir(data_path))
# Out:
# ['train', 'val']

# %%
print(len(os.listdir(train_healthy_data))) #length of healthy training sounds
print(len(os.listdir(train_unhealthy_data))) #length of unhelathy training sounds 
print('TOTAL TRAIN SOUNDS:', len(os.listdir(train_healthy_data)) + len(os.listdir(train_unhealthy_data)))
# Out:
# 2575
# 665
# TOTAL TRAIN SOUNDS: 3240

# %% [markdown]
# # EDA and Visualization

# %%
x = np.array([len(os.listdir(train_healthy_data)),len(os.listdir(train_unhealthy_data))])
labels = ['Healthy', 'Unhealthy']
colors = {'Healthy': 'chartreuse','Unhealthy': 'teal' }
plt.pie(x, labels = labels, autopct = '%.0f%%', radius= 1.5, colors = [colors[key] for key in labels], textprops={'fontsize': 16})
plt.show()

# %% [markdown]
# #### the figure shows imbalanced data so we need to fix it later

# %% [markdown]
# ## *Healthy sound*

# %% [markdown]
# Normal breath sounds occur in all parts of the chest area, including above the collarbones and at the bottom of the rib cage. normal lung sound is kind of smoothly, low-pitched sound, in contrast with unhealthy lung sound, which is wheezing or high-pitched sound.

# %% [markdown]
# **Frequency and Pitch** :
# The pitch or frequency of breath sounds can be described as high or low.
#
# **Intensity** :
# The intensity or loudness of breath sounds can be described as normal, decreased (diminished), or absent. Intensity is usually higher in the bases than at the top of the lungs (apices).

# %%
# Choose random soud from healthy folder
random_healthy= np.random.randint(0,len(os.listdir(train_healthy_data))) 
healthy_sound = os.listdir(train_healthy_data)[random_healthy]
healthy_sound_address = train_healthy_data+healthy_sound
healthy_sound_sample,sample_rate = librosa.load(healthy_sound_address)
ipd.Audio(healthy_sound_sample,rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Waveform

# %% [markdown]
# Sound is the pressure of air propagates to our ear. Digital audio file is gotten from a sound sensor that can detects sound waves and converting it to electrical signals.

# %% [markdown]
# Specifically, it's telling us about the wave's displacement, and how it changes over time.

# %%
plt.figure(figsize=(20,5))
librosa.display.waveplot(healthy_sound_sample, sr = sample_rate)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# X axis, represents time. In this case, our graph is showing a 28-second interval.
# Y-axis measures displacement of air molecules.This is where amplitude comes in. It measures how much a molecule is displaced from its resting position.

# %% [markdown]
# ### Spectrum

# %% [markdown]
# A sound spectrum is a representation of a sound – usually a short sample of a sound – in terms of the amount of vibration at each individual frequency. It is usually presented as a graph of either power or pressure as a function of frequency. The power or pressure is usually measured in decibels and the frequency is measured in vibrations per second (or hertz, abbreviation Hz) or thousands of vibrations per second (kilohertz, abbreviation kHz).
#
# The spectrum expresses the frequency composition of the sound and is obtained by analyzing the sound. A sound spectrum is usually represented in a coordinate plane where the frequency f is plotted along the axis of abscissas and the amplitude A, or intensity, of a harmonic component with a given frequency is plotted along the axis of ordinates.

# %%
fft_healthy = np.fft.fft(healthy_sound_sample)
magnitude_healthy = np.abs(fft_healthy)
freq_healthy = np.linspace(0,sample_rate, len(magnitude_healthy)) 
half_freq = freq_healthy[:int(len(freq_healthy)/2)]
half_magnitude = magnitude_healthy[:int(len(freq_healthy)/2)]

plt.figure(figsize=(12,8))
plt.plot(half_freq,half_magnitude)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.show()

# %% [markdown]
# ### Spectogram

# %% [markdown]
# For us, as human, we sense a sound not only on a particular time by its intensity, but also by its pitch. The pitch is the frequency of the sound - higher pitch corresponding to higher frequency and vice versa. So, to have a representation which is closer to our brain, we can add another dimension - the frequency - to our representation, which is the Spectrogram.

# %% [markdown]
# A spectrogram is a visual representation of the spectrum of frequencies of a signal as it varies with time. When applied to an audio signal, spectrograms are sometimes called sonographs, voiceprints, or voicegrams.
#
# Spectrograms are used extensively in the fields of music, linguistics, sonar, radar, speech processing,seismology, and others. Spectrograms of audio can be used to identify spoken words phonetically, and to analyse the various calls of animals.it can be generated by an optical spectrometer, a bank of band-pass filters, by Fourier transform or by a wavelet transform.

# %%
# STFT -> spectrogram
hop_length = 512 # in num. of samples
n_fft = 2048 # window in num. of samples

# calculate duration hop length and window in seconds
hop_length_duration = float(hop_length)/sample_rate
n_fft_duration = float(n_fft)/sample_rate

print("STFT hop length duration is: {}s".format(hop_length_duration))
print("STFT window duration is: {}s".format(n_fft_duration))

# perform stft
stft_healthy = librosa.stft(healthy_sound_sample, n_fft=n_fft, hop_length=hop_length)

# calculate abs values on complex numbers to get magnitude
spectrogram = np.abs(stft_healthy)
log_spectrogram = librosa.amplitude_to_db(spectrogram)

# display spectrogram
plt.figure(figsize=(20,5))
librosa.display.specshow(log_spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.set_cmap("YlOrBr")
plt.title("Spectrogram")
# Out:
# STFT hop length duration is: 0.023219954648526078s
# STFT window duration is: 0.09287981859410431s
# Text(0.5, 1.0, 'Spectrogram')

# %% [markdown]
# we have an image that represents a sound. X-axis is for time, y-axis is for frequency and the color is for intensity

# %% [markdown]
# ### MFCCs

# %% [markdown]
# Speech Recognition is a supervised learning task. In the speech recognition problem input will be the audio signal and we have to predict the text from the audio signal. We can’t take the raw audio signal as input to our model because there will be a lot of noise in the audio signal. It is observed that extracting features from the audio signal and using it as input to the base model will produce much better performance than directly considering raw audio signal as input. MFCC is the widely used technique for extracting the features from the audio signal.

# %% [markdown]
# in sound processing, the mel-frequency cepstrum (MFC) is a representation of the short-term power spectrum of a sound, based on a linear cosine transform of a log power spectrum on a nonlinear mel scale of frequency.
#
# Mel-frequency cepstral coefficients (MFCCs) are coefficients that collectively make up an MFC. They are derived from a type of cepstral representation of the audio clip (a nonlinear "spectrum-of-a-spectrum"). The difference between the cepstrum and the mel-frequency cepstrum is that in the MFC, the frequency bands are equally spaced on the mel scale, which approximates the human auditory system's response more closely than the linearly-spaced frequency bands used in the normal spectrum. This frequency warping can allow for better representation of sound, for example, in audio compression.

# %% [markdown]
# **MFCCs are commonly derived as follows:**
#
# 1- Take the Fourier transform of (a windowed excerpt of) a signal.
#
# 2- Map the powers of the spectrum obtained above onto the mel scale, using triangular overlapping windows or alternatively, cosine overlapping windows.
#
# 3- Take the logs of the powers at each of the mel frequencies.
#
# 4- Take the discrete cosine transform of the list of mel log powers, as if it were a signal.
#
# 5- The MFCCs are the amplitudes of the resulting spectrum.

# %%
# MFCCs
# extract 25 MFCCs
MFCCs = librosa.feature.mfcc(healthy_sound_sample, sample_rate, n_fft=n_fft, hop_length=hop_length, n_mfcc=25)

# display MFCCs
plt.figure(figsize=(20,5))
librosa.display.specshow(MFCCs, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
plt.set_cmap("YlOrBr")
plt.title("MFCCs")

# show plots
plt.show()

# %% [markdown]
# ## Unhealthy sound

# %% [markdown]
# **Decreased or absent(unhealthy) breast sounds may be noted in a number of different conditions:**
#
# 1- When there is fluid around the lungs, such as with pleural effusion.
#
# 2- When there is air around the lungs, as with a pneumothorax.
#
# 3- If the lungs are overinflated, such as with emphysema.
#
# 4- When airflow to a region of the lungs is reduced, such as with an obstruction due to a tumor or foreign body.
#
# 5- If the thickness of the chest wall is increased, such as with obesity.

# %%
# Choose random soud from unhealthy folder
random_unhealthy= np.random.randint(0,len(os.listdir(train_unhealthy_data))) 
unhealthy_sound = os.listdir(train_unhealthy_data)[random_unhealthy]
unhealthy_sound_address = train_unhealthy_data+unhealthy_sound
unhealthy_sound_sample,sample_rate = librosa.load(unhealthy_sound_address)
ipd.Audio(unhealthy_sound_sample,rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Waveform

# %%
plt.figure(figsize=(20,5))
librosa.display.waveplot(unhealthy_sound_sample, sr = sample_rate)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# ### Spectrum

# %%
fft_unhealthy = np.fft.fft(unhealthy_sound_sample)
magnitude_unhealthy = np.abs(fft_unhealthy)
freq_unhealthy = np.linspace(0,sample_rate, len(magnitude_unhealthy)) 
half_freq = freq_unhealthy[:int(len(freq_unhealthy)/2)]
half_magnitude = magnitude_unhealthy[:int(len(freq_unhealthy)/2)]

plt.figure(figsize=(12,8))
plt.plot(half_freq,half_magnitude)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.show()

# %% [markdown]
# ### Spectogram

# %%
# STFT -> spectrogram
hop_length = 512 # in num. of samples
n_fft = 2048 # window in num. of samples

# calculate duration hop length and window in seconds
hop_length_duration = float(hop_length)/sample_rate
n_fft_duration = float(n_fft)/sample_rate

print("STFT hop length duration is: {}s".format(hop_length_duration))
print("STFT window duration is: {}s".format(n_fft_duration))

# perform stft
stft_unhealthy = librosa.stft(unhealthy_sound_sample, n_fft=n_fft, hop_length=hop_length)

# calculate abs values on complex numbers to get magnitude
spectrogram = np.abs(stft_unhealthy)
log_spectrogram = librosa.amplitude_to_db(spectrogram)

# display spectrogram
plt.figure(figsize=(20,5))
librosa.display.specshow(log_spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.set_cmap("YlOrBr")
plt.title("Spectrogram")
# Out:
# STFT hop length duration is: 0.023219954648526078s
# STFT window duration is: 0.09287981859410431s
# Text(0.5, 1.0, 'Spectrogram')

# %% [markdown]
# ### MFCCs

# %%
# MFCCs
# extract 25 MFCCs
MFCCs = librosa.feature.mfcc(unhealthy_sound_sample, sample_rate, n_fft=n_fft, hop_length=hop_length, n_mfcc=25)

# display MFCCs
plt.figure(figsize=(15,10))
librosa.display.specshow(MFCCs, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
#plt.set_cmap("YlOrBr")
plt.title("MFCCs")

# show plots
plt.show()

# %% [markdown]
# # Loading data

# %%
def load_file_data (folder, file_names, duration=10, sr=22050):
    input_length=sr*duration
    # function to load files and extract features
    # file_names = glob.glob(os.path.join(folder, '*.wav'))
    data = []
    for file_name in file_names:
        try:
            sound_file=folder+file_name
            print ("load file ",sound_file)
            # use kaiser_fast technique for faster extraction
            X, sr = librosa.load( sound_file, sr=sr, duration=duration,res_type='kaiser_fast') 
            dur = librosa.get_duration(y=X, sr=sr)
            # pad audio file same duration
            if (round(dur) < duration):
                print ("fixing audio lenght :", file_name)
                y = librosa.util.fix_length(X, input_length)                
            #normalized raw audio 
            # y = audio_norm(y)            
            # extract normalized mfcc feature from data
            mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sr, n_mfcc=25).T,axis=0)             
        except Exception as e:
            print("Error encountered while parsing file: ", file)        
        feature = np.array(mfccs).reshape([-1,1])
        data.append(feature)
    return data

# %% [markdown]
# #  preprocessing :

# %% [markdown]
# ## *Encoding*

# %%
# simple encoding of categories, limited to 3 types
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# Map label text to integer
CLASSES = ['healthy','unhealthy']
NB_CLASSES=len(CLASSES)

# Map integer value to text labels
label_to_int = {k:v for v,k in enumerate(CLASSES)}
print (label_to_int)
print (" ")
# map integer to label text
int_to_label = {v:k for k,v in label_to_int.items()}
print(int_to_label)
# Out:
# {'healthy': 0, 'unhealthy': 1}
#
# {0: 'healthy', 1: 'unhealthy'}

# %%
# KHz
SAMPLE_RATE = 22050
# seconds
MAX_SOUND_CLIP_DURATION=10

healthy_files = fnmatch.filter(os.listdir(train_healthy_data), '*.wav')
healthy_sounds = load_file_data (folder=train_healthy_data, file_names = healthy_files, duration=MAX_SOUND_CLIP_DURATION)
healthy_labels = [0 for items in healthy_files]



print ("loaded dataset")
# Out:
# load file  /content/drive/MyDrive/heart_sound/train//healthy/e
wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0092.wav
# fixing audio lenght : b0092.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0373.wav
# fixing audio lenght : b0373.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0188.wav
# fixing audio lenght : b0188.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0430.wav
# fixing audio lenght : b0430.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0138.wav
# fixing audio lenght : b0138.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0179.wav
# fixing audio lenght : b0179.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0317.wav
# fixing audio lenght : b0317.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0321.wav
# fixing audio lenght : b0321.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0166.wav
# fixing audio lenght : b0166.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0354.wav
# fixing audio lenght : b0354.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0090.wav
# fixing audio lenght : b0090.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0442.wav
# fixing audio lenght : b0442.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0026.wav
# fixing audio lenght : b0026.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0151.wav
# fixing audio lenght : b0151.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0223.wav
# fixing audio lenght : b0223.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0114.wav
# fixing audio lenght : b0114.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0060.wav
# fixing audio lenght : b0060.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0376.wav
# fixing audio lenght : b0376.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0014.wav
# fixing audio lenght : b0014.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0458.wav
# fixing audio lenght : b0458.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0473.wav
# fixing audio lenght : b0473.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0231.wav
# fixing audio lenght : b0231.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0441.wav
# fixing audio lenght : b0441.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0489.wav
# fixing audio lenght : b0489.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0366.wav
# fixing audio lenght : b0366.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0360.wav
# fixing audio lenght : b0360.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0274.wav
# fixing audio lenght : b0274.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0215.wav
# fixing audio lenght : b0215.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0104.wav
# fixing audio lenght : b0104.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0306.wav
# fixing audio lenght : b0306.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0475.wav
# fixing audio lenght : b0475.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0254.wav
# fixing audio lenght : b0254.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0285.wav
# fixing audio lenght : b0285.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0070.wav
# fixing audio lenght : b0070.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0024.wav
# fixing audio lenght : b0024.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0103.wav
# fixing audio lenght : b0103.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0282.wav
# fixing audio lenght : b0282.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0072.wav
# fixing audio lenght : b0072.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0411.wav
# fixing audio lenght : b0411.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0339.wav
# fixing audio lenght : b0339.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0291.wav
# fixing audio lenght : b0291.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0462.wav
# fixing audio lenght : b0462.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0169.wav
# fixing audio lenght : b0169.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0372.wav
# fixing audio lenght : b0372.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0218.wav
# fixing audio lenght : b0218.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0213.wav
# fixing audio lenght : b0213.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0135.wav
# fixing audio lenght : b0135.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0078.wav
# fixing audio lenght : b0078.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0095.wav
# fixing audio lenght : b0095.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0061.wav
# fixing audio lenght : b0061.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0270.wav
# fixing audio lenght : b0270.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/a0325.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0168.wav
# fixing audio lenght : b0168.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0276.wav
# fixing audio lenght : b0276.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0374.wav
# fixing audio lenght : b0374.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0256.wav
# fixing audio lenght : b0256.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0049.wav
# fixing audio lenght : b0049.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0269.wav
# fixing audio lenght : b0269.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0128.wav
# fixing audio lenght : b0128.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0379.wav
# fixing audio lenght : b0379.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0124.wav
# fixing audio lenght : b0124.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0296.wav
# fixing audio lenght : b0296.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0403.wav
# fixing audio lenght : b0403.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0343.wav
# fixing audio lenght : b0343.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0358.wav
# fixing audio lenght : b0358.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0305.wav
# fixing audio lenght : b0305.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0210.wav
# fixing audio lenght : b0210.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/a0405.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0131.wav
# fixing audio lenght : b0131.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0407.wav
# fixing audio lenght : b0407.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0340.wav
# fixing audio lenght : b0340.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/a0298.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/a0337.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/a0330.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0111.wav
# fixing audio lenght : b0111.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0165.wav
# fixing audio lenght : b0165.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/a0334.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0042.wav
# fixing audio lenght : b0042.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy/b0371.wav
# fixing audio lenght : b0371.wav
# load file  /content/drive/MyDrive/heart_sound/train//healthy
wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0239.wav
# fixing audio lenght : b0239.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0382.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0356.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0292.wav
# fixing audio lenght : b0292.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0398.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0372.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0257.wav
# fixing audio lenght : b0257.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0003.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0032.wav
# fixing audio lenght : b0032.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0033.wav
# fixing audio lenght : b0033.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0025.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0362.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0005.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0280.wav
# fixing audio lenght : b0280.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0358.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0370.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0011.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0012.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0137.wav
# fixing audio lenght : b0137.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0399.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0021.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0048.wav
# fixing audio lenght : b0048.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0390.wav
# fixing audio lenght : b0390.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0009.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0008.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0391.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0361.wav
# fixing audio lenght : b0361.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0397.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0471.wav
# fixing audio lenght : b0471.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0390.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0369.wav
# fixing audio lenght : b0369.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0376.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0428.wav
# fixing audio lenght : b0428.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0368.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0013.wav
# fixing audio lenght : b0013.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0023.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0022.wav
# fixing audio lenght : b0022.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0369.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0243.wav
# fixing audio lenght : b0243.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0344.wav
# fixing audio lenght : b0344.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0383.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0155.wav
# fixing audio lenght : b0155.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0031.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0307.wav
# fixing audio lenght : b0307.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0004.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0418.wav
# fixing audio lenght : b0418.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0278.wav
# fixing audio lenght : b0278.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0403.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0159.wav
# fixing audio lenght : b0159.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0018.wav
# fixing audio lenght : b0018.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0341.wav
# fixing audio lenght : b0341.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0253.wav
# fixing audio lenght : b0253.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0450.wav
# fixing audio lenght : b0450.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0242.wav
# fixing audio lenght : b0242.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0002.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0436.wav
# fixing audio lenght : b0436.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0273.wav
# fixing audio lenght : b0273.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0015.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0467.wav
# fixing audio lenght : b0467.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0408.wav
# fixing audio lenght : b0408.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0374.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0004.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0232.wav
# fixing audio lenght : b0232.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0395.wav
# fixing audio lenght : b0395.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0299.wav
# fixing audio lenght : b0299.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0010.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0388.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0043.wav
# fixing audio lenght : b0043.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0024.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0130.wav
# fixing audio lenght : b0130.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0380.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0402.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0001.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0385.wav
# fixing audio lenght : b0385.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0379.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0096.wav
# fixing audio lenght : b0096.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0334.wav
# fixing audio lenght : b0334.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0262.wav
# fixing audio lenght : b0262.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0016.wav
# fixing audio lenght : b0016.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0012.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0365.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0030.wav
# fixing audio lenght : b0030.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0354.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0081.wav
# fixing audio lenght : b0081.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0360.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0392.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0068.wav
# fixing audio lenght : b0068.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0387.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0446.wav
# fixing audio lenght : b0446.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0377.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0357.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0017.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0010.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0409.wav
# fixing audio lenght : b0409.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0384.wav
# fixing audio lenght : b0384.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0484.wav
# fixing audio lenght : b0484.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0389.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0014.wav
# fixing audio lenght : d0014.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0279.wav
# fixing audio lenght : b0279.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/a0363.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0248.wav
# fixing audio lenght : b0248.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/c0014.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0117.wav
# fixing audio lenght : b0117.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0233.wav
# fixing audio lenght : b0233.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/b0176.wav
# fixing audio lenght : b0176.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00114.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00135.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00359.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00766.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01665.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00670.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01289.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00321.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00880.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00477.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00537.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00605.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01421.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01263.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e02126.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01461.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01215.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e02101.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0033.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01531.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01375.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00475.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01511.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00539.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00601.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0051.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00847.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e00619.wav
# fixing audio lenght : e00619.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01160.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01494.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e01351.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/d0019.wav
# fixing audio lenght : d0019.wav
# load file  /content/drive/MyDrive/heart_sound/train//unhealthy/e
wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0037.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0023.wav
# fixing audio lenght : b0023.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0197.wav
# fixing audio lenght : b0197.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0136.wav
# fixing audio lenght : b0136.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/d0008.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00539.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0148.wav
# fixing audio lenght : b0148.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00591.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00176.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0248.wav
# fixing audio lenght : b0248.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0054.wav
# fixing audio lenght : b0054.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0037.wav
# fixing audio lenght : b0037.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00120.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0002.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00275.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0017.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/c0002.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00528.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/c0004.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00195.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0048.wav
# fixing audio lenght : b0048.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00622.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0023.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00670.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00601.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0013.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0239.wav
# fixing audio lenght : b0239.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0015.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0120.wav
# fixing audio lenght : b0120.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0051.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00605.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0030.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00373.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0003.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00321.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00295.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0043.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0130.wav
# fixing audio lenght : b0130.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00457.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0032.wav
# fixing audio lenght : b0032.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0235.wav
# fixing audio lenght : b0235.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00191.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0022.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0054.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00328.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/d0004.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0042.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00020.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0013.wav
# fixing audio lenght : b0013.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0117.wav
# fixing audio lenght : b0117.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0039.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/d0002.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00114.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/d0009.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/c0001.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0036.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0164.wav
# fixing audio lenght : b0164.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00135.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0048.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00266.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0033.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00140.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0046.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0014.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0232.wav
# fixing audio lenght : b0232.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0046.wav
# fixing audio lenght : b0046.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0155.wav
# fixing audio lenght : b0155.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00142.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/d0003.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00537.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00475.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00435.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00536.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0034.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0006.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00336.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0033.wav
# fixing audio lenght : b0033.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00359.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0008.wav
# fixing audio lenght : b0008.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00648.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0159.wav
# fixing audio lenght : b0159.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0242.wav
# fixing audio lenght : b0242.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0096.wav
# fixing audio lenght : b0096.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00562.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00087.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0021.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00304.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00523.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0004.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0221.wav
# fixing audio lenght : b0221.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0041.wav
# fixing audio lenght : b0041.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00526.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0045.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00305.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0208.wav
# fixing audio lenght : b0208.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00216.wav
# fixing audio lenght : e00216.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0026.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00228.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00456.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/c0031.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00603.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0063.wav
# fixing audio lenght : b0063.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0008.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0233.wav
# fixing audio lenght : b0233.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00048.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00097.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0243.wav
# fixing audio lenght : b0243.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0057.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00059.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00477.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0081.wav
# fixing audio lenght : b0081.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0047.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0031.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0040.wav
# fixing audio lenght : b0040.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0176.wav
# fixing audio lenght : b0176.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0018.wav
# fixing audio lenght : b0018.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0137.wav
# fixing audio lenght : b0137.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0224.wav
# fixing audio lenght : b0224.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0022.wav
# fixing audio lenght : b0022.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00551.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0040.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0140.wav
# fixing audio lenght : b0140.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00619.wav
# fixing audio lenght : e00619.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0077.wav
# fixing audio lenght : b0077.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0005.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0044.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00071.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00330.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0043.wav
# fixing audio lenght : b0043.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00627.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0056.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/e00388.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0001.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0016.wav
# fixing audio lenght : b0016.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/b0106.wav
# fixing audio lenght : b0106.wav
# load file  /content/drive/MyDrive/heart_sound/val//unhealthy/a0052.wav
# loaded test dataset

# %% [markdown]
# ## *concatenation*

# %%
x_data = np.concatenate((healthy_sounds, unhealthy_sounds))

y_data = np.concatenate((healthy_labels,unhealthy_labels))

test_x = np.concatenate((val_healthy_sounds,val_unhealthy_sounds))
test_y = np.concatenate((val_healthy_labels,val_unhealthy_labels))

print ("combined training data record: ",len(y_data), len(test_y))
# Out:
# combined training data record:  3240 301

# %% [markdown]
# ## *train_test_validation split*

# %%
# shuffle - whether or not to shuffle the data before splitting. If shuffle=False then stratify must be None.
# random_state is the seed used by the random number generator; If RandomState instance, random_state is the random number generator; If None, the random number generator is the RandomState instance used by np.random.

seed = 100
# split data into Train, Validation and Test
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, train_size=0.8, random_state=seed, shuffle=True)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, train_size=0.8, random_state=seed, shuffle=True)

# One-Hot encoding for classes
y_train = np.array(tf.keras.utils.to_categorical(y_train, len(CLASSES)))
y_test = np.array(tf.keras.utils.to_categorical(y_test, len(CLASSES)))
y_val = np.array(tf.keras.utils.to_categorical(y_val, len(CLASSES)))
test_y=np.array(tf.keras.utils.to_categorical(test_y, len(CLASSES)))

# %%
print ("label shape: ", y_data.shape)
print ("data size of the array: : %s" % y_data.size)
print ("length of one array element in bytes: ", y_data.itemsize)
print ("total bytes consumed by the elements of the array: ", y_data.nbytes)
print (y_data[1])
print ("")
print ("audio data shape: ", x_data.shape)
print ("data size of the array: : %s" % x_data.size)
print ("length of one array element in bytes: ", x_data.itemsize)
print ("total bytes consumed by the elements of the array: ", x_data.nbytes)
print ("")
print ("training data shape: ", x_train.shape)
print ("training label shape: ", y_train.shape)
print ("")
print ("validation data shape: ", x_val.shape)
print ("validation label shape: ", y_val.shape)
print ("")
print ("test data shape: ", x_test.shape)
print ("test label shape: ", y_test.shape)
# Out:
# label shape:  (3240,)
# data size of the array: : 3240
# length of one array element in bytes:  8
# total bytes consumed by the elements of the array:  25920
# 0
#
# audio data shape:  (3240, 25, 1)
# data size of the array: : 81000
# length of one array element in bytes:  4
# total bytes consumed by the elements of the array:  324000
#
# training data shape:  (2073, 25, 1)
# training label shape:  (2073, 2)
#
# validation data shape:  (519, 25, 1)
# validation label shape:  (519, 2)
#
# test data shape:  (648, 25, 1)
# test label shape:  (648, 2)

# %% [markdown]
# ## *Correct imbalnced data using class weight*

# %%
TRAIN_IMG_COUNT = 3240
COUNT_0 = 2575  #healthy
COUNT_1 = 665 #unhealthy
weight_for_0 = TRAIN_IMG_COUNT / (2 * COUNT_0)
weight_for_1 = TRAIN_IMG_COUNT / (2 * COUNT_1)
class_weight = {0: weight_for_0, 1: weight_for_1}
class_weight
# Out:
# {0: 0.629126213592233, 1: 2.43609022556391}

# %% [markdown]
# # LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, LSTM, Bidirectional
from tensorflow.keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint,TensorBoard,ProgbarLogger
#from tensorflow.keras.utils import np_utils
from sklearn import metrics 
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import itertools

# %%
model = Sequential()
model.add(Bidirectional(LSTM(128, dropout=0.05, recurrent_dropout=0.20, return_sequences=True), input_shape = (25,1)))
#model.add(Bidirectional(LSTM(32,  return_sequences=False)))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(32, activation='relu'))
model.add(Flatten())

model.add(Dense(2, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='Adamax', metrics=['acc'])


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 25, 256)          133120
#  l)
#
#  dense (Dense)               (None, 25, 128)           32896
#
#  dense_1 (Dense)             (None, 25, 64)            8256
#
#  dropout (Dropout)           (None, 25, 64)            0
#
#  dense_2 (Dense)             (None, 25, 32)            2080
#
#  dense_3 (Dense)             (None, 25, 32)            1056
#
#  dropout_1 (Dropout)         (None, 25, 32)            0
#
#  dense_4 (Dense)             (None, 25, 32)            1056
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense_5 (Dense)             (None, 2)                 1602
#
# =================================================================
# Total params: 180,066
# Trainable params: 180,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
print ("training started..... please wait.")
# training
history=model.fit(x_train, y_train, 
                  batch_size=16, 
                  epochs=20,
                  validation_data=(x_val, y_val)) 

print ("training finised!")
# Out:
# training started..... please wait.
# Epoch 1/20
# 130/130 [==============================] - 19s 108ms/step - loss: 0.4649 - acc: 0.7940 - val_loss: 0.4293 - val_acc: 0.7630
# Epoch 2/20
# 130/130 [==============================] - 13s 102ms/step - loss: 0.4049 - acc: 0.7969 - val_loss: 0.4106 - val_acc: 0.7630
# Epoch 3/20
# 130/130 [==============================] - 13s 103ms/step - loss: 0.3869 - acc: 0.7969 - val_loss: 0.3914 - val_acc: 0.7842
# Epoch 4/20
# 130/130 [==============================] - 13s 103ms/step - loss: 0.3730 - acc: 0.8172 - val_loss: 0.3736 - val_acc: 0.8324
# Epoch 5/20
# 130/130 [==============================] - 13s 104ms/step - loss: 0.3675 - acc: 0.8403 - val_loss: 0.3572 - val_acc: 0.8439
# Epoch 6/20
# 130/130 [==============================] - 13s 102ms/step - loss: 0.3562 - acc: 0.8447 - val_loss: 0.3508 - val_acc: 0.8497
# Epoch 7/20
# 130/130 [==============================] - 13s 103ms/step - loss: 0.3509 - acc: 0.8514 - val_loss: 0.3438 - val_acc: 0.8497
# Epoch 8/20
# 130/130 [==============================] - 14s 104ms/step - loss: 0.3398 - acc: 0.8582 - val_loss: 0.3421 - val_acc: 0.8593
# Epoch 9/20
# 130/130 [==============================] - 14s 105ms/step - loss: 0.3353 - acc: 0.8606 - val_loss: 0.3287 - val_acc: 0.8516
# Epoch 10/20
# 130/130 [==============================] - 14s 104ms/step - loss: 0.3430 - acc: 0.8562 - val_loss: 0.3364 - val_acc: 0.8478
# Epoch 11/20
# 130/130 [==============================] - 13s 103ms/step - loss: 0.3308 - acc: 0.8596 - val_loss: 0.3290 - val_acc: 0.8574
# Epoch 12/20
# 130/130 [==============================] - 14s 105ms/step - loss: 0.3264 - acc: 0.8538 - val_loss: 0.3501 - val_acc: 0.8497
# Epoch 13/20
# 130/130 [==============================] - 13s 103ms/step - loss: 0.3260 - acc: 0.8649 - val_loss: 0.3242 - val_acc: 0.8593
# Epoch 14/20
# 130/130 [==============================] - 13s 103ms/step - loss: 0.3186 - acc: 0.8620 - val_loss: 0.3168 - val_acc: 0.8536
# Epoch 15/20
# 130/130 [==============================] - 13s 104ms/step - loss: 0.3199 - acc: 0.8587 - val_loss: 0.3118 - val_acc: 0.8593
# Epoch 16/20
# 130/130 [==============================] - 14s 104ms/step - loss: 0.3073 - acc: 0.8644 - val_loss: 0.3231 - val_acc: 0.8420
# Epoch 17/20
# 130/130 [==============================] - 14s 104ms/step - loss: 0.3108 - acc: 0.8726 - val_loss: 0.3185 - val_acc: 0.8516
# Epoch 18/20
# 130/130 [==============================] - 13s 103ms/step - loss: 0.3023 - acc: 0.8722 - val_loss: 0.3070 - val_acc: 0.8613
# Epoch 19/20
# 130/130 [==============================] - 14s 104ms/step - loss: 0.3097 - acc: 0.8654 - val_loss: 0.3099 - val_acc: 0.8574
# Epoch 20/20
# 130/130 [==============================] - 14s 104ms/step - loss: 0.3046 - acc: 0.8683 - val_loss: 0.3106 - val_acc: 0.8593
# training finised!

# %%
#Plot Keras History
#Plot loss and accuracy for the training and validation set.
def plot_history(history):
    loss_list = [s for s in history.history.keys() if 'loss' in s and 'val' not in s]
    val_loss_list = [s for s in history.history.keys() if 'loss' in s and 'val' in s]
    acc_list = [s for s in history.history.keys() if 'acc' in s and 'val' not in s]
    val_acc_list = [s for s in history.history.keys() if 'acc' in s and 'val' in s]
    if len(loss_list) == 0:
        print('Loss is missing in history')
        return 
    plt.figure(figsize=(22,10))
    ## As loss always exists
    epochs = range(1,len(history.history[loss_list[0]]) + 1)
    ## Accuracy
    plt.figure(221, figsize=(20,10))
    ## Accuracy
    # plt.figure(2,figsize=(14,5))
    plt.subplot(221, title='Accuracy')
    for l in acc_list:
        plt.plot(epochs, history.history[l], 'b', label='Training accuracy (' + str(format(history.history[l][-1],'.5f'))+')')
    for l in val_acc_list:    
        plt.plot(epochs, history.history[l], 'g', label='Validation accuracy (' + str(format(history.history[l][-1],'.5f'))+')')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    ## Loss
    plt.subplot(222, title='Loss')
    for l in loss_list:
        plt.plot(epochs, history.history[l], 'b', label='Training loss (' + str(str(format(history.history[l][-1],'.5f'))+')'))
    for l in val_loss_list:
        plt.plot(epochs, history.history[l], 'g', label='Validation loss (' + str(str(format(history.history[l][-1],'.5f'))+')'))    
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# plot history
plot_history(history)

# %% [markdown]
# # prediction

# %%
# make a prediction
y_pred = model.predict(x_test, batch_size=5)
#check scores
scores = model.evaluate(x_test, y_test)
print ("Model evaluation accuracy: ", round(scores[1]*100),"%")
# Out:
# 21/21 [==============================] - 0s 15ms/step - loss: 0.2641 - acc: 0.8812
# Model evaluation accuracy:  88 %

# %% [markdown]
# # saving and loading model

# %%
model.save("lung_sound1.h5")

# %%
from google.colab import files 
files.download('lung_sound1.h5')

# %%
y_pred = np.asarray(model.predict(x_test, batch_size=32))
y_pred = np.argmax(y_pred,axis=1)

# %%
target_names = ["Healthy", "Unhealthy"]
print(classification_report(y_test.argmax(axis=1), y_pred, target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.91      0.94      0.93       527
#    Unhealthy       0.71      0.61      0.66       121
#
#     accuracy                           0.88       648
#    macro avg       0.81      0.78      0.79       648
# weighted avg       0.88      0.88      0.88       648

# %% [markdown]
# #Treatment options for abnormal breath sounds:

# %% [markdown]
# Treatment options for abnormal breath sounds depend on your diagnosis. Your doctor takes the cause and the severity of your symptoms into consideration when recommending a treatment.
#
# Medications are often prescribed to clear up infections or to open the airways. However, in severe cases, such as fluid in the lungs or an obstruction in the airways, hospitalization may be necessary.
#
# If you have asthma, COPD, or bronchitis, your doctor will probably prescribe breathing treatments to open the airways. People with asthma may be given an inhaler or other medications to use daily. This can prevent asthma attacks and decrease inflammation of the airways.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
